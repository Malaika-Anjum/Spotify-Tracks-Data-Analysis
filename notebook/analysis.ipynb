# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("ggplot")

# %%
df = pd.read_csv(r"E:\AIBootCamp\Spotify_Tracks_Analysis\data\spotify_tracks.csv")

# %%
df.head()
# Out:
#    Unnamed: 0                track_id                 artists  \
# 0           0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1           1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2           2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3           3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4           4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# ...

# %%
df.tail()
# Out:
#         Unnamed: 0                track_id           artists  \
# 113995      113995  2C3TZjDRiAzdyViavDJ217     Rainy Lullaby
# 113996      113996  1hIz5L4IB9hN3WRYPOCGPw     Rainy Lullaby
# 113997      113997  6x8ZfSoqDjuNa5SVP5QjvX     Cesária Evora
# 113998      113998  2e6sXL2bYv4bSz6VTdnfLs  Michael W. Smith
# 113999      113999  2hETkH7cOfqmz3LqZDHZf5     Cesária Evora
#
#                                                album_name  \
# 113995  #mindfulness - Soft Rain for Mindful Meditatio...
# 113996  #mindfulness - Soft Rain for Mindful Meditatio...
# 113997                                            Best Of
# 113998                                  Change Your World
# 113999                                     Miss Perfumado
#
#                  track_name  popularity  duration_ms  explicit  danceability  \
# 113995  Sleep My Little Boy          21       384999     False         0.172
# 113996     Water Into Light          22       385000     False         0.174
# ...

# %%
df.shape
# Out:
# (114000, 21)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'track_id', 'artists', 'album_name', 'track_name',
#        'popularity', 'duration_ms', 'explicit', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature',
#        'track_genre'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 114000 entries, 0 to 113999
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        114000 non-null  int64
#  1   track_id          114000 non-null  str
#  2   artists           113999 non-null  str
#  3   album_name        113999 non-null  str
#  4   track_name        113999 non-null  str
#  5   popularity        114000 non-null  int64
#  6   duration_ms       114000 non-null  int64
#  7   explicit          114000 non-null  bool
#  8   danceability      114000 non-null  float64
#  9   energy            114000 non-null  float64
#  10  key               114000 non-null  int64
#  11  loudness          114000 non-null  float64
#  12  mode              114000 non-null  int64
#  13  speechiness       114000 non-null  float64
#  14  acousticness      114000 non-null  float64
#  15  instrumentalness  114000 non-null  float64
# ...

# %%
df.describe()
# Out:
#           Unnamed: 0     popularity   duration_ms   danceability  \
# count  114000.000000  114000.000000  1.140000e+05  114000.000000
# mean    56999.500000      33.238535  2.280292e+05       0.566800
# std     32909.109681      22.305078  1.072977e+05       0.173542
# min         0.000000       0.000000  0.000000e+00       0.000000
# 25%     28499.750000      17.000000  1.740660e+05       0.456000
# 50%     56999.500000      35.000000  2.129060e+05       0.580000
# 75%     85499.250000      50.000000  2.615060e+05       0.695000
# max    113999.000000     100.000000  5.237295e+06       0.985000
#
#               energy            key       loudness           mode  \
# count  114000.000000  114000.000000  114000.000000  114000.000000
# mean        0.641383       5.309140      -8.258960       0.637553
# std         0.251529       3.559987       5.029337       0.480709
# min         0.000000       0.000000     -49.531000       0.000000
# ...

# %%
df.describe(include=["object", "string"])
# Out:
#                       track_id      artists                  album_name  \
# count                   114000       113999                      113999
# unique                   89741        31437                       46579
# top     6S3JlDAGk3uu3NtZbPnuhS  The Beatles  Alternative Christmas 2022
# freq                         9          279                         195
#
#              track_name track_genre
# count            113999      114000
# unique            73602         114
# top     Run Rudolph Run    acoustic
# freq                151        1000

# %%
df.sample(5)
# Out:
#         Unnamed: 0                track_id            artists  \
# 19408        19408  4T9NkV23VehFveulDtI7KC     Brett Eldredge
# 110562      110562  2iU4ZlFm68vUQ5u3Xd4lN3              Jilax
# 112178      112178  7GawgSohrHICmemM8RZauh              Tuhan
# 51279        51279  0OvC1QkWdBI3ORrp2lEhNO  Wazir Patar;Azaad
# 36292        36292  2efj0AL33odgMfU2qir4Su             Renaud
#
#               album_name      track_name  popularity  duration_ms  explicit  \
# 19408   New Country Hits        Hideaway           0       163360     False
# 110562            Clouds          Clouds          42       500281     False
# 112178          Motorola        Marlboro          44       123275     False
# 51279    Keep It Gangsta  Pind Da Riwaaz          62       188181      True
# 36292            Métèque      Le Métèque          36       199733     False
#
#         danceability  energy  ...  loudness  mode  speechiness  acousticness  \
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# track_id            0
# artists             1
# album_name          1
# track_name          1
# popularity          0
# duration_ms         0
# explicit            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# track_genre         0
# dtype: int64

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df.isnull(),cbar=False)
plt.savefig(r"E:\AIBootCamp\Spotify_Tracks_Analysis\images\missing_values.png")

plt.show()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df=df.drop_duplicates()

# %%
df.nunique()
# Out:
# Unnamed: 0          114000
# track_id             89741
# artists              31437
# album_name           46579
# track_name           73602
# popularity             101
# duration_ms          50697
# explicit                 2
# danceability          1174
# energy                2083
# key                     12
# loudness             19480
# mode                     2
# speechiness           1489
# acousticness          5061
# instrumentalness      5346
# liveness              1722
# valence               1790
# tempo                45653
# time_signature           5
# track_genre            114
# dtype: int64

# %%
df["track_genre"].nunique()
# Out:
# 114

# %%
df=df.drop(columns=["Unnamed: 0"])

# %%
df["duration_min"]=df["duration_ms"]/60000

# %%
df.mean(numeric_only=True)
# Out:
# popularity              33.238535
# duration_ms         228029.153114
# explicit                 0.085500
# danceability             0.566800
# energy                   0.641383
# key                      5.309140
# loudness                -8.258960
# mode                     0.637553
# speechiness              0.084652
# acousticness             0.314910
# instrumentalness         0.156050
# liveness                 0.213553
# valence                  0.474068
# tempo                  122.147837
# time_signature           3.904035
# duration_min             3.800486
# dtype: float64

# %%
df.median(numeric_only=True)
# Out:
# popularity              35.000000
# duration_ms         212906.000000
# explicit                 0.000000
# danceability             0.580000
# energy                   0.685000
# key                      5.000000
# loudness                -7.004000
# mode                     1.000000
# speechiness              0.048900
# acousticness             0.169000
# instrumentalness         0.000042
# liveness                 0.132000
# valence                  0.464000
# tempo                  122.017000
# time_signature           4.000000
# duration_min             3.548433
# dtype: float64

# %%
df.std(numeric_only=True)
# Out:
# popularity              22.305078
# duration_ms         107297.712645
# explicit                 0.279626
# danceability             0.173542
# energy                   0.251529
# key                      3.559987
# loudness                 5.029337
# mode                     0.480709
# speechiness              0.105732
# acousticness             0.332523
# instrumentalness         0.309555
# liveness                 0.190378
# valence                  0.259261
# tempo                   29.978197
# time_signature           0.432621
# duration_min             1.788295
# dtype: float64

# %%
df.var(numeric_only=True)
# Out:
# popularity          4.975165e+02
# duration_ms         1.151280e+10
# explicit            7.819044e-02
# danceability        3.011689e-02
# energy              6.326687e-02
# key                 1.267351e+01
# loudness            2.529423e+01
# mode                2.310813e-01
# speechiness         1.117933e-02
# acousticness        1.105713e-01
# instrumentalness    9.582420e-02
# liveness            3.624367e-02
# valence             6.721630e-02
# tempo               8.986923e+02
# time_signature      1.871608e-01
# duration_min        3.198000e+00
# dtype: float64

# %%
df.sort_values("popularity",ascending=False).head(20)
# Out:
#                      track_id                     artists  \
# 81051  3nqQXoyQOWXiESFLlDF1hG        Sam Smith;Kim Petras
# 20001  3nqQXoyQOWXiESFLlDF1hG        Sam Smith;Kim Petras
# 51664  2tTmW7RDtMQtBk7m2rYeSw            Bizarrap;Quevedo
# 89411  5ww2BF9slyYgNOk37BlC4u               Manuel Turizo
# 30003  4uUG5RXrOk84mYEfFvj3cK     David Guetta;Bebe Rexha
# 20008  4uUG5RXrOk84mYEfFvj3cK     David Guetta;Bebe Rexha
# 81210  4uUG5RXrOk84mYEfFvj3cK     David Guetta;Bebe Rexha
# 88410  5ww2BF9slyYgNOk37BlC4u               Manuel Turizo
# 67356  5ww2BF9slyYgNOk37BlC4u               Manuel Turizo
# 68303  5ww2BF9slyYgNOk37BlC4u               Manuel Turizo
# 88405  6Sq7ltF9Qa7SNFBsV5Cogx  Bad Bunny;Chencho Corleone
# 68304  1IHWl5LamUGEuP4ozKQSXZ                   Bad Bunny
# 67359  1IHWl5LamUGEuP4ozKQSXZ                   Bad Bunny
# 89405  1IHWl5LamUGEuP4ozKQSXZ                   Bad Bunny
# 67358  6Sq7ltF9Qa7SNFBsV5Cogx  Bad Bunny;Chencho Corleone
# ...

# %%
df[df["popularity"]>90]
# Out:
#                      track_id               artists  \
# 2003   2QjOHCTQ1Jl3zawyYOpxh6     The Neighbourhood
# 3003   2QjOHCTQ1Jl3zawyYOpxh6     The Neighbourhood
# 15013  3JvKfv6T31zO0ini8iNItO             Tom Odell
# 20000  5IgjP7X4th6nMNDh4akUHb           Chris Brown
# 20001  3nqQXoyQOWXiESFLlDF1hG  Sam Smith;Kim Petras
# ...                       ...                   ...
# 89500  31i56LZnwE6uSu3exoHjtB             Bad Bunny
# 89554  41oY4WCTj5kccfesTVFnvN      Bad Bunny;Jhayco
# 91001  5XeFesFbtLpXzIVDNQP22n        Arctic Monkeys
# 91002  2QjOHCTQ1Jl3zawyYOpxh6     The Neighbourhood
# 91003  4h9wh7iOZ0GGn8QVp4RAOB           OneRepublic
#
#                                               album_name  \
# 2003                                         I Love You.
# 3003                                         I Love You.
# 15013                             Long Way Down (Deluxe)
# 20000                                  Indigo (Extended)
# ...

# %%
df[df["explicit"]==True]
# Out:
#                       track_id               artists               album_name  \
# 59      2gRKq9rIC5i1zuxp06zJWH      Chord Overstreet       What's Left of You
# 243     3M6NL7PxIDZ3ArfPrBUTUP           Days N Daze  Show Me the Blueprints.
# 247     5DUAKXpyv3nL50PnAQbPS0              Get Dead   Tall Cans & Loose Ends
# 284     0njuNwIyB3DoBHC0SFUkOr  Andrew Foy;Renee Foy       You Broke Me First
# 298     1MGIxsVtqK2npdPmI8Dj0D           Days N Daze          Rogue Taxidermy
# ...                        ...                   ...                      ...
# 112963  1lBqaMn59aIxdg3h0fXtm1                Ati242              GHETTO STAR
# 112965  27ySu5G3hIHmxMp30Gzoo7                  Rota                MetaVerse
# 112972  4iehSC3GZEt4FUUUbqN4us                  Rota                MetaVerse
# 112976  2GEbjuHvth4NpnWKzYWCJX                 Hidra                 Yolculuk
# 112983  1E6l6wLjVXURKH2If5BG2M          Contra;İtaat             Hitz En Şitz
#
# ...

# %%
df[df["danceability"]>0.8]
# Out:
#                       track_id                            artists  \
# 448     6339iq4yAm87arKgnNc922                            Zee Avi
# 616     7pxbZ29k1LJXvOdd2e5Bdn                         Us The Duo
# 656     3zjr7jirhGwvqGuuJuIxjg               Andrew Foy;Renee Foy
# 663     12qmPGMrOCogibc7qyxT9s                        Gen Hoshino
# 713     1z2fSrYZqrO5tMqzULn9OD                       Tyrone Wells
# ...                        ...                                ...
# 112869  3kVFYB1LkUYH4Q8cjpIJq6                      Sagopa Kajmer
# 112909  3jxn92KU8l5RPjwLTGlMyg  Arem Ozguc;Arman Aydin;Jordan Rys
# 112913  59YZrBAIg1tDH8squLd7gY                         Cem Adrian
# 113696  797ikuM3k4gkjaxStQnxgW            Cesária Evora;Ismaël Lô
# 113942  1QwLpfmZ6NPzjk3YFXkl0E                      Cesária Evora
#
#                                   album_name  \
# 448              Acoustic Christmas Campfire
# 616                                  Shotgun
# ...

# %%
df.groupby("track_genre")["popularity"].mean()
# Out:
# track_genre
# acoustic       42.483
# afrobeat       24.399
# alt-rock       33.943
# alternative    24.337
# ambient        44.191
#                 ...
# techno         39.042
# trance         37.635
# trip-hop       34.460
# turkish        40.698
# world-music    41.873
# Name: popularity, Length: 114, dtype: float64

# %%
df.groupby("track_genre")["energy"].mean()
# Out:
# track_genre
# acoustic       0.435368
# afrobeat       0.702812
# alt-rock       0.754173
# alternative    0.720030
# ambient        0.237162
#                  ...
# techno         0.746413
# trance         0.845272
# trip-hop       0.622363
# turkish        0.609804
# world-music    0.532987
# Name: energy, Length: 114, dtype: float64

# %%
df.groupby("track_genre").agg({
    "popularity":"mean",
    "energy":"mean",
    "danceability":"mean",
    "tempo":"mean"
})
# Out:
#              popularity    energy  danceability       tempo
# track_genre
# acoustic         42.483  0.435368      0.549593  119.010624
# afrobeat         24.399  0.702812      0.669580  119.213337
# alt-rock         33.943  0.754173      0.534493  124.634404
# alternative      24.337  0.720030      0.559927  122.232394
# ambient          44.191  0.237162      0.367867  111.113129
# ...                 ...       ...           ...         ...
# techno           39.042  0.746413      0.684348  128.255482
# trance           37.635  0.845272      0.583409  133.276726
# trip-hop         34.460  0.622363      0.634695  118.743616
# turkish          40.698  0.609804      0.616077  120.367607
# world-music      41.873  0.532987      0.414572  121.393711
#
# [114 rows x 4 columns]

# %%
pd.pivot_table(
    df,
    values="popularity",
    index="track_genre",
    columns="explicit",
    aggfunc="mean"
)
# Out:
# explicit         False      True
# track_genre
# acoustic     43.148734  30.346154
# afrobeat     24.359470  26.555556
# alt-rock     33.623941  39.321429
# alternative  24.552632  23.237805
# ambient      44.125628  57.200000
# ...                ...        ...
# techno       38.935318  43.038462
# trance       37.531697  42.227273
# trip-hop     34.541361  32.733333
# turkish      40.964194  39.743119
# world-music  41.873000        NaN
#
# [114 rows x 2 columns]

# %%
corr=df.corr(numeric_only=True)

# %%
plt.figure(figsize=(12,8))
sns.heatmap(corr,annot=True)
plt.savefig(r"E:\AIBootCamp\Spotify_Tracks_Analysis\images\correlation.png")

plt.show()

# %%
plt.figure(figsize=(12,8))
sns.histplot(df["energy"])
plt.savefig(r"E:\AIBootCamp\Spotify_Tracks_Analysis\images\energy.png")

plt.show()

# %%
plt.figure(figsize=(15,6))
sns.countplot(
    data=df,
    y="track_genre",
    order=df["track_genre"].value_counts().index[:15]
)

plt.savefig(r"E:\AIBootCamp\Spotify_Tracks_Analysis\images\track_genre.png")

# %%
sns.violinplot(
    x="explicit",
    y="popularity",
    data=df
)

plt.savefig(r"E:\AIBootCamp\Spotify_Tracks_Analysis\images\violenplot.png")

# %%
sns.boxplot(x=df["popularity"])

plt.savefig(r"E:\AIBootCamp\Spotify_Tracks_Analysis\images\boxplot.png")

# %%
sns.scatterplot(
    data=df,
    x="energy",
    y="popularity"
)

plt.savefig(r"E:\AIBootCamp\Spotify_Tracks_Analysis\images\scatterplot.png")

# %%
sns.pairplot(df[
[
"popularity",
"energy",
"danceability",
"tempo",
"valence"
]])

plt.savefig(r"E:\AIBootCamp\Spotify_Tracks_Analysis\images\pairplot.png")

# %%
sns.regplot(
    x="energy",
    y="popularity",
    data=df
)

plt.savefig(r"E:\AIBootCamp\Spotify_Tracks_Analysis\images\regplot.png")

# %%
df["Long Song"]=df["duration_min"]>5

# %%
df["Hit"]=df["popularity"]>=80

# %%
df.to_csv("data/spotify_cleaned.csv",index=False)
